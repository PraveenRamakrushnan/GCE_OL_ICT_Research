# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenRamakrushnan/GCE_OL_ICT_Research/blob/main/Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Dataset Skeleton

# %%
import pandas as pd

# Create empty dataset structure
data = {
    "Year": [],             # Year of the past paper (ex: 2018, 2019)
    "QuestionNumber": [],   # Question number (ex: 1, 2, 3)
    "QuestionType": [],     # MCQ / Structured
    "Topic": [],            # Database / Networking / Programming etc.
    "QuestionText": []      # The actual question text
}

df = pd.DataFrame(data)

# Save CSV into Google Drive
path = "/content/drive/MyDrive/Research/data/past_papers.csv"
df.to_csv(path, index=False)

print("✅ Empty dataset created at:", path)
# Out:
# ✅ Empty dataset created at: /content/drive/MyDrive/Research/data/past_papers.csv
